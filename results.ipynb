# %%
from src.utils.config import import_history
from src.utils.plots import plot_metrics
from src.training.models import EfficientNetEncoder

# %%
history = import_history("res/history.json")

plot_metrics(history["training"])

# %%
plot_metrics(history["validation"])
