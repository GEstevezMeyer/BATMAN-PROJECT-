# %%
from src.utils.config import import_history,load_model,import_config
from src.utils.plots import *
from src.training.models import EfficientNetEncoder
from src.training.pipeline import SOCOFingDataset,create_ValidationDataLoader
# Out:
# device in use: cuda

# %%
history = import_history("res/history.json")
config = import_config("config.toml")
model = load_model(EfficientNetEncoder(config["model"]["dimension"]))

dataset = SOCOFingDataset("DATA/SOCOFing/Real")
dataloader = create_ValidationDataLoader(dataset)
# Out:
# -----------------
# Executing: import_history
# ------------------
# ------------------
# Finishing: import_history
# ------------------
# -----------------
# Executing: import_config
# ------------------
# ------------------
# Finishing: import_config
# ------------------
# -----------------
# Executing: load_model
# ------------------
# ------------------
# Finishing: load_model
# ------------------
# -----------------
# Executing: create_metadata
# ------------------
# 100%|██████████| 6000/6000 [00:00<00:00, 1994754.60it/s]
# ------------------
# Finishing: create_metadata
# ------------------

# %%
plot_metrics(history["training"])

# %%
plot_metrics(history["validation"])

# %%
plot_pca(model,dataloader)
# Out:
# 100%|██████████| 94/94 [00:17<00:00,  5.48it/s]

# %%
plot_tsne(model,dataloader)
# Out:
# 100%|██████████| 94/94 [00:18<00:00,  5.20it/s]
